# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamgundawarNYU/Big-Data-Project-Group-16/blob/main/misc-datasets-notebooks/NYPD_Shooting_Incident_Data_(Historic).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**BIG DATA PROJECT**
#
# ### NYPD Shooting Incident Data (Historic)
# Link to Dataset (https://data.cityofnewyork.us/Public-Safety/NYPD-Shooting-Incident-Data-Historic-/833y-fsy8)
#
# ### DATA CLEANING AT SCALE

# %% [markdown]
# #### Mounting Google Drive to Google Collab Notebook to Load the Data Set
#
# Make sure you have the dataset in your Google Drive and you mount your drive to the Colab.
#
# The file should be at the following path: `gdrive/My Drive/NYPD_Arrest_Data_Year_to_Date.csv`

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #### Importing required and Necessary Libraries for cleaning the data present in the data set

# %%
import numpy as np
import pandas as pd
import io

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.2.0)
# Requirement already satisfied: py4j==0.10.9.2 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.2)

# %% [markdown]
# # **Running Pyspark in Colab**
#
# To run spark in Colab, we need to first install all the dependencies in Colab environment i.e. Apache Spark 2.3.2 with hadoop 2.7, Java 8 and Findspark to locate the spark in the system. The tools installation can be carried out inside the Jupyter Notebook of the Colab. One important note is that if you are new in Spark, it is better to avoid Spark 2.4.0 version since some people have already complained about its compatibility issue with python.
# Follow the steps to install the dependencies:

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://dlcdn.apache.org/spark/spark-3.2.0/spark-3.2.0-bin-hadoop3.2.tgz
# !tar xf spark-3.2.0-bin-hadoop3.2.tgz
# !pip install -q findspark

# %% [markdown]
# Now that you installed Spark and Java in Colab, it is time to set the environment path which enables you to run Pyspark in your Colab environment. Set the location of Java and Spark by running the following code:

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.2.0-bin-hadoop3.2"

# %% [markdown]
# Run a local spark session to test your installation:

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# #### Reading the Data Set CSV File using `spark.read.csv()` Function

# %%
df = spark.read.csv("/content/gdrive/MyDrive/Big Data/NYPD_Shooting_Incident_Data__Historic_.csv", inferSchema=True, header =True)

# %%
df.count()
# Out:
# 23585

# %% [markdown]
# #### Get Data Type for each column present in the Data Set

# %%
df.printSchema()
# Out:
# root
#  |-- INCIDENT_KEY: integer (nullable = true)
#  |-- OCCUR_DATE: string (nullable = true)
#  |-- OCCUR_TIME: string (nullable = true)
#  |-- BORO: string (nullable = true)
#  |-- PRECINCT: integer (nullable = true)
#  |-- JURISDICTION_CODE: integer (nullable = true)
#  |-- LOCATION_DESC: string (nullable = true)
#  |-- STATISTICAL_MURDER_FLAG: boolean (nullable = true)
#  |-- PERP_AGE_GROUP: string (nullable = true)
#  |-- PERP_SEX: string (nullable = true)
#  |-- PERP_RACE: string (nullable = true)
#  |-- VIC_AGE_GROUP: string (nullable = true)
#  |-- VIC_SEX: string (nullable = true)
#  |-- VIC_RACE: string (nullable = true)
#  |-- X_COORD_CD: double (nullable = true)
#  |-- Y_COORD_CD: double (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Lon_Lat: string (nullable = true)

# %% [markdown]
# #### Outputing the List of Columns in the Data Set

# %%
df.columns
# Out:
# ['INCIDENT_KEY',
#  'OCCUR_DATE',
#  'OCCUR_TIME',
#  'BORO',
#  'PRECINCT',
#  'JURISDICTION_CODE',
#  'LOCATION_DESC',
#  'STATISTICAL_MURDER_FLAG',
#  'PERP_AGE_GROUP',
#  'PERP_SEX',
#  'PERP_RACE',
#  'VIC_AGE_GROUP',
#  'VIC_SEX',
#  'VIC_RACE',
#  'X_COORD_CD',
#  'Y_COORD_CD',
#  'Latitude',
#  'Longitude',
#  'Lon_Lat']

# %% [markdown]
# #### Get top 10 rows of the arrests dataframe

# %%
df.show(n=10)
# Out:
# +------------+----------+----------+--------+--------+-----------------+-------------+-----------------------+--------------+--------+---------+-------------+-------+--
------------+--------------------+
# only showing top 10 rows

# %% [markdown]
# ## We see that the columns `X_COORD_CD`,`Y_COORD_CD`,`Latitude` and `Longitude` conveys the same data as `New Georeferenced Column`.
#
# #### Hence, we drop those columns and keep only `New Georeferenced Column` column in our cleaned dataset.

# %%
df = df.drop('X_COORD_CD','Y_COORD_CD', 'Latitude', 'Longitude')

# %%
df.columns
# Out:
# ['INCIDENT_KEY',
#  'OCCUR_DATE',
#  'OCCUR_TIME',
#  'BORO',
#  'PRECINCT',
#  'JURISDICTION_CODE',
#  'LOCATION_DESC',
#  'STATISTICAL_MURDER_FLAG',
#  'PERP_AGE_GROUP',
#  'PERP_SEX',
#  'PERP_RACE',
#  'VIC_AGE_GROUP',
#  'VIC_SEX',
#  'VIC_RACE',
#  'Lon_Lat']

# %% [markdown]
# #### Removing all the **duplicate** entries

# %%
df = df.drop_duplicates()

# %%
df.count()
# Out:
# 23585

# %%
df.distinct().count()
# Out:
# 23585

# %% [markdown]
# ## Find Count of Null, None, NaN of All DataFrame Columns

# %%
df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df.columns]
   ).show()

# %% [markdown]
# #### Get top 5 rows where Arrest Date is NaN

# %%
df.where(col('OCCUR_DATE').isNull()).show(n=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe88f93088c5> in <module>()
# ----> 1 df.where(col('ARREST_DATE').isNull()).show(n=5)
#
# NameError: name 'df' is not defined

# %% [markdown]
# There are no rows where Arrest Date is not present which is the expected scenario since the arrest would have happened on a particular day.

# %%
df = df.filter(df.OCCUR_DATE.isNotNull())

# %%
df.show(100)
# Out:
# +------------+----------+----------+-------------+--------+-----------------+--------------------+-----------------------+--------------+--------+--------------+-------------+-------+--------------+--------------------+
# |INCIDENT_KEY|OCCUR_DATE|OCCUR_TIME|         BORO|PRECINCT|JURISDICTION_CODE|       LOCATION_DESC|STATISTICAL_MURDER_FLAG|PERP_AGE_GROUP|PERP_SEX|     PERP_RACE|VIC_AGE_GROUP|VIC_SEX|      VIC_RACE|             Lon_Lat|
# +------------+----------+----------+-------------+--------+-----------------+--------------------+-----------------------+--------------+--------+--------------+-------------+-------+--------------+--------------------+
# |    74925351|10/05/2010|  16:04:00|     BROOKLYN|      67|                0|     COMMERCIAL BLDG|                  false|         25-44|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.943490...|
# |   198404597|06/12/2019|  19:37:00|     BROOKLYN|      77|                0|      GROCERY/BODEGA|                   true|         25-44|       M|         BLACK|        45-64|      M|         BLACK|POINT (-73.941653...|
# |   220294221|11/09/2020|  16:48:00|       QUEENS|     101|                0|      GROCERY/BODEGA|                  false|          null|    null|          null|        25-44|      M|WHITE HISPANIC|POINT (-73.763268...|
# |    77758734|03/16/2011|  19:13:00|       QUEENS|     113|                0|           PVT HOUSE|                  false|         18-24|       F|         BLACK|        18-24|      M|         BLACK|POINT (-73.775909...|
# |    71608993|03/04/2010|  18:27:00|        BRONX|      50|                2|MULTI DWELL - PUB...|                   true|         18-24|       M|         BLACK|        18-24|      M|BLACK HISPANIC|POINT (-73.908011...|
# |    33008213|07/09/2007|  00:20:00|        BRONX|      47|                0|                null|                  false|         18-24|       F|WHITE HISPANIC|        18-24|      M|WHITE HISPANIC|POINT (-73.847607...|
# |    46141344|05/03/2008|  03:13:00|        BRONX|      40|                0|                null|                   true|          null|    null|          null|        25-44|      M|         BLACK|POINT (-73.925622...|
# |    86093515|08/04/2012|  22:29:00|        BRONX|      46|                0|                null|                   true|         18-24|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.899665...|
# |    34057961|08/29/2007|  11:02:00|STATEN ISLAND|     120|                0|   BEAUTY/NAIL SALON|                  false|         25-44|       M|         BLACK|        25-44|      M|         BLACK|POINT (-74.166234...|
# |    80149332|08/04/2011|  23:15:00|        BRONX|      42|                0|MULTI DWELL - APT...|                  false|          null|    null|          null|        25-44|      M|         BLACK|POINT (-73.895200...|
# |   208532947|01/26/2020|  00:27:00|        BRONX|      43|                0|      BAR/NIGHT CLUB|                  false|         25-44|       M|WHITE HISPANIC|        45-64|      M|WHITE HISPANIC|POINT (-73.864116...|
# |   144448394|07/13/2015|  01:01:00|        BRONX|      52|                0|                null|                  false|         18-24|       M|         BLACK|        18-24|      M|BLACK HISPANIC|POINT (-73.875021...|
# |   148364097|12/07/2015|  22:05:00|STATEN ISLAND|     120|                0|           PVT HOUSE|                  false|         45-64|       M|         BLACK|        25-44|      M|         BLACK|POINT (-74.081246...|
# |    80432271|08/24/2011|  04:05:00|        BRONX|      41|                0|      GROCERY/BODEGA|                  false|         25-44|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73
       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.906206...|
# |   217594075|09/08/2020|  22:40:00|     BROOKLYN|      79|                2|MULTI DWELL - PUB...|                  false|          null|    null|          null|        45-64|      F|WHITE HISPANIC|POINT (-73.949751...|
# |    64554617|08/10/2009|  00:40:00|       QUEENS|     114|                2|MULTI DWELL - PUB...|                  false|           <18|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.943422...|
# |    73455060|06/29/2010|  02:17:00|       QUEENS|     103|                0|MULTI DWELL - APT...|                  false|         18-24|       M|         BLACK|        25-44|      M|         BLACK|POINT (-73.770868...|
# |   203678796|10/12/2019|  06:30:00|        BRONX|      42|                0|MULTI DWELL - PUB...|                  false|          null|    null|          null|        25-44|      M|WHITE HISPANIC|POINT (-73.907281...|
# |    23749365|08/07/2006|  02:06:00|    MANHATTAN|      25|                0|                null|                  false|         18-24|       M|WHITE HISPANIC|        25-44|      M|BLACK HISPANIC|POINT (-73.937229...|
# |   187954071|09/21/2018|  06:52:00|       QUEENS|     114|                0|MULTI DWELL - APT...|                  false|         45-64|       M|         BLACK|        25-44|      F|         WHITE|POINT (-73.893039...|
# |    72152729|04/10/2010|  02:00:00|     BROOKLYN|      73|                2|MULTI DWELL - PUB...|                   true|          null|    null|          null|        18-24|      M|         BLACK|POINT (-73.919798...|
# |    28892743|05/07/2007|  16:52:00|     BROOKLYN|      73|                2|MULTI DWELL - PUB...|                  false|       UNKNOWN|       U|       UNKNOWN|        18-24|      M|         BLACK|POINT (-73.915729...|
# |    87915624|11/30/2012|  21:36:00|     BROOKLYN|      73|                2|MULTI DWELL - PUB...|                  false|         18-24|       M|         BLACK|          <18|      M|         BLACK|POINT (-73.919798...|
# |    73950768|08/02/2010|  21:39:00|     BROOKLYN|      94|                2|MULTI DWELL - PUB...|                  false|         18-24|       M|         BLACK|        25-44|      M|         BLACK|POINT (-73.941407...|
# |    46803515|05/28/2008|  15:54:00|STATEN ISLAND|     120|                0|                null|                  false|           <18|       M|         BLACK|          <18|      M|WHITE HISPANIC|POINT (-74.084236...|
# |    80541204|08/31/2011|  19:18:00|     BROOKLYN|      73|                2|MULTI DWELL - PUB...|                  false|         18-24|       M|WHITE HISPANIC|          <18|      M|         BLACK|POINT (-73.904338...|
# |    10879209|03/31/2006|  01:13:00|    MANHATTAN|      23|                0|    RESTAURANT/DINER|                  false|         18-24|       M|WHITE HISPANIC|        18-24|      M|         BLACK|POINT (-73.954476...|
# |    73541312|07/06/2010|  04:00:00|        BRONX|      40|                0|                null|                   true|         18-24|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.922759...|
# |    67678775|11/09/2009|  18:14:00|     BROOKLYN|      73|                0|                null|                   true|         18-24|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.913554...|
# +------------+----------+----------+-------------+--------+-----------------+--------------------+-----------------------+--------------+--------+--------------+-------------+-------+--------------+--------------------+
# only showing top 100 rows

# %% [markdown]
# Check if minimum and maximum values of date and time are valid or not.
#
# 1. The minimum value should not be less than January 1, 2021.
#
# 2. And the maximum value should not be greater than the current date.

# %%
## Minimum value of the column in pyspark
df.agg({'ARREST_DATE': 'min'}).show()
# Out:
# +----------------+
# |min(ARREST_DATE)|
# +----------------+
# |      01/01/2021|
# +----------------+

# %%
## Maximum value of the column in pyspark
df.agg({'ARREST_DATE': 'max'}).show()
# Out:
# +----------------+
# |max(ARREST_DATE)|
# +----------------+
# |      09/30/2021|
# +----------------+

# %% [markdown]
# ## TODO: Revisit
# **Some basic data quality checks are as below:**
# 1. Check if there are no garbage values in law category column. The valid values are: 'FELONY', 'VIOLATION', 'MISDEMEANOR'.
# Check for the value `I`.
# 2. Check if there are no misspellings in Borough Name. There should be 5 distinct boroughs: Manhattan, Bronx, Queens, Brooklyn, Staten Island. We implement unique method, in case of misspellings multiple values of the same borough would be returned.
# 3. Ideally, key code should contain only 3 digits. Implementing a check below to see if there are any invalid values for the key code.

# %%
df.select('PERP_SEX').distinct().show()
# Out:
# +--------+
# |PERP_SEX|
# +--------+
# |       F|
# |    null|
# |       M|
# |       U|
# +--------+

# %%
df.groupBy('PERP_SEX').count().show()
# Out:
# +--------+-----+
# |PERP_SEX|count|
# +--------+-----+
# |       F|  335|
# |       M|13490|
# |       U| 1499|
# |    null| 8261|
# +--------+-----+

# %% [markdown]
# ### Checks for Borough Name

# %%
df.select('BORO').distinct().show()
# Out:
# +-------------+
# |         BORO|
# +-------------+
# |       QUEENS|
# |     BROOKLYN|
# |        BRONX|
# |    MANHATTAN|
# |STATEN ISLAND|
# +-------------+

# %% [markdown]
# We can see there are no invalid values for the Borough names and thus no need for additional data correction for the same.

# %%
df.where(col('BORO').isNull()).show()
# Out:
# +------------+----------+----------+----+--------+-----------------+-------------+-----------------------+--------------+--------+---------+-------------+-------+--------+-------+
# |INCIDENT_KEY|OCCUR_DATE|OCCUR_TIME|BORO|PRECINCT|JURISDICTION_CODE|LOCATION_DESC|STATISTICAL_MURDER_FLAG|PERP_AGE_GROUP|PERP_SEX|PERP_RACE|VIC_AGE_GROUP|VIC_SEX|VIC_RACE|Lon_Lat|
# +------------+----------+----------+----+--------+-----------------+-------------+-----------------------+--------------+--------+---------+-------------+-------+--------+-------+
# +------------+----------+----------+----+--------+-----------------+-------------+-----------------------+--------------+--------+---------+-------------+-------+--------+-------+

# %% [markdown]
# #### Dropping Rows where Borough Name is NULL

# %%
df = df.filter(df.BORO.isNotNull())

# %%
df.count()
# Out:
# 23585

# %%
df.filter(df.BORO.isNull()).show()
# Out:
# +------------+----------+----------+----+--------+-----------------+-------------+-----------------------+--------------+--------+---------+-------------+-------+--------+-------+
# |INCIDENT_KEY|OCCUR_DATE|OCCUR_TIME|BORO|PRECINCT|JURISDICTION_CODE|LOCATION_DESC|STATISTICAL_MURDER_FLAG|PERP_AGE_GROUP|PERP_SEX|PERP_RACE|VIC_AGE_GROUP|VIC_SEX|VIC_RACE|Lon_Lat|
# +------------+----------+----------+----+--------+-----------------+-------------+-----------------------+--------------+--------+---------+-------------+-------+--------+-------+
# +------------+----------+----------+----+--------+-----------------+-------------+-----------------------+--------------+--------+---------+-------------+-------+--------+-------+

# %%
pip install openclean humanfriendly
# Out:
# Collecting openclean
#   Downloading openclean-0.2.1-py3-none-any.whl (5.2 kB)
# Collecting humanfriendly
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 3.0 MB/s
# Collecting openclean-core==0.4.1
#   Downloading openclean_core-0.4.1-py3-none-any.whl (267 kB)
#      |████████████████████████████████| 267 kB 28.6 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (0.16.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (1.1.5)
# Collecting refdata>=0.2.0
#   Downloading refdata-0.2.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (1.4.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (2.8.2)
# Collecting histore>=0.4.0
#   Downloading histore-0.4.1-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 55.6 MB/s
# Collecting jsonschema>=3.2.0
#   Downloading jsonschema-4.2.1-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 5.4 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (0.3.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (2.23.0)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (1.4.4)
# Collecting flowserv-core>=0.8.0
#   Downloading flowserv_core-0.9.2-py3-none-any.whl (260 kB)
#      |████████████████████████████████| 260 kB 45.5 MB/s
# Collecting jellyfish
#   Downloading jellyfish-0.8.9.tar.gz (137 kB)
#      |████████████████████████████████| 137 kB 57.3 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 39.3 MB/s
# Collecting gitpython
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 71.2 MB/s
# Requirement already satisfied: SQLAlchemy>=1.3.18 in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.4.27)
# Collecting pyyaml-include
#   Downloading pyyaml_include-1.2.post2-py3-none-any.whl (20 kB)
# Collecting paramiko
#   Downloading paramiko-2.8.1-py2.py3-none-any.whl (206 kB)
#      |████████████████████████████████| 206 kB 68.2 MB/s
# Collecting passlib
#   Downloading passlib-1.7.4-py2.py3-none-any.whl (525 kB)
#      |████████████████████████████████| 525 kB 73.3 MB/s
# Requirement already satisfied: Click in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (7.1.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from histore>=0.4.0->openclean-core==0.4.1->openclean) (5.4.8)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (0.18.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (4.8.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (21.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (3.6.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->openclean-core==0.4.1->openclean) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->openclean-core==0.4.1->openclean) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->openclean-core==0.4.1->openclean) (1.15.0)
# Requirement already satisfied: pooch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean) (1.5.2)
# Collecting datasize>=1.0.0
#   Downloading datasize-1.0.0.tar.gz (149 kB)
#      |████████████████████████████████| 149 kB 55.2 MB/s
# Collecting tableprint
#   Downloading tableprint-0.9.1-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.4.1->openclean) (21.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=1.3.18->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.1.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (3.10.0.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.4.1->openclean) (3.0.6)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.5 MB/s
# Collecting cryptography>=2.5
#   Downloading cryptography-36.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 36.8 MB/s
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 42.0 MB/s
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (2.21)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 72.8 MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->openclean-core==0.4.1->openclean) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->openclean-core==0.4.1->openclean) (3.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from tableprint->refdata>=0.2.0->openclean-core==0.4.1->openclean) (0.2.5)
# Building wheels for collected packages: datasize, jellyfish
#   Building wheel for datasize (setup.py) ... done
#   Created wheel for datasize: filename=datasize-1.0.0-py2.py3-none-any.whl size=155047 sha256=8b44b92c1f916dbfd2cb0f4a589974c271a9e2907993fb84810a048b19586bcd
#   Stored in directory: /root/.cache/pip/wheels/f7/b5/32/d8836896da6aca7f9c5748670ea6110d1385c262bf3abcca30
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.8.9-cp37-cp37m-linux_x86_64.whl size=73227 sha256=48932e70d3f5b90785048fd77de5d416daec1055bc1446bfb9306e7dbd4f7655
#   Stored in directory: /root/.cache/pip/wheels/32/a9/ef/5d8742e72deaf0d1de327a180d008c2c0299367581800ea73f
# Successfully built datasize jellyfish
# Installing collected packages: smmap, pyyaml, pynacl, gitdb, cryptography, bcrypt, tableprint, pyyaml-include, passlib, paramiko, jsonschema, gitpython, datasize, refdata, jellyfish, histore, flowserv-core, openclean-core, openclean, humanfriendly
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 2.6.0
#     Uninstalling jsonschema-2.6.0:
#       Successfully uninstalled jsonschema-2.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbclient 0.5.9 requires jupyter-client>=6.1.5, but you have jupyter-client 5.3.5 which is incompatible.
# Successfully installed bcrypt-3.2.0 cryptography-36.0.0 datasize-1.0.0 flowserv-core-0.9.2 gitdb-4.0.9 gitpython-3.1.24 histore-0.4.1 humanfriendly-10.0 jellyfish-0.8.9 jsonschema-4.2.1 openclean-0.2.1 openclean-core-0.4.1 paramiko-2.8.1 passlib-1.7.4 pynacl-1.4.0 pyyaml-5.4.1 pyyaml-include-1.2.post2 refdata-0.2.0 smmap-5.0.0 tableprint-0.9.1

# %%
import openclean
from openclean.data.source.socrata import Socrata

# Download the full 'NYPD Complaint Data Historic' dataset.
# Note that the downloaded full dataset file is about 380 MB in size! Use the
# alternative data file with 10,000 rows that is included in the repository if
# you do not want to download the full data file.

import gzip
import humanfriendly
import os

dataset = Socrata().dataset('833y-fsy8')

# By default, this example uses a small sample of the full dataset that
# is included in the 'data' subfolder within this repository.
#datafile = './data/qgea-i56i.tsv.gz'

# Remove the comment for this line if you want to use the full dataset.
datafile = './833y-fsy8.tsv.gz'


# Download file only if it does not exist already.
if not os.path.isfile(datafile):
    with gzip.open(datafile, 'wb') as f:
        print('Downloading ...\n')
        dataset.write(f)


fsize = humanfriendly.format_size(os.stat(datafile).st_size)
print("Using '{}' in file {} of size {}".format(dataset.name, datafile, fsize))
# Out:
# Downloading ...
#
# Using 'NYPD Shooting Incident Data (Historic)' in file ./833y-fsy8.tsv.gz of size 1.22 MB

# %%
# Due to the size of the full dataset file, we make use of openclean's
# stream operator to avoid having to load the dataset into main-memory.

from openclean.pipeline import stream

ds = stream(datafile)

# %%
bor = ds.select('BORO')

bor1 = bor.to_df()

# %%
bor1.dropna(inplace=True)

# %%
bor1.isnull().values.any()
# Out:
# False

# %%
from openclean.function.matching.base import DefaultStringMatcher
from openclean.function.matching.fuzzy import FuzzySimilarity
from openclean.data.mapping import Mapping

VOCABULARY = ['BROOKLYN','MANHATTAN','STATEN ISLAND','BRONX','QUEENS']

matcher = DefaultStringMatcher(
    vocabulary=VOCABULARY,
    similarity=FuzzySimilarity()
)

map = Mapping()
for query in bor1['BORO']:
    map.add(query, matcher.find_matches(query))

print(map)
# Out:
# Mapping(<class 'list'>, {'BRONX': [StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), StringMatch(term='BRONX', score=1), Strin ...

# %%
from openclean.function.eval.domain import Lookup
from openclean.operator.transform.update import update
from openclean.function.eval.base import Col


fixed = update(bor1, 'BORO', Lookup(columns=['BORO'], mapping=map.to_lookup(), default=Col('BORO')))

print(fixed['BORO'].unique())
# Out:
# /usr/local/lib/python3.7/dist-packages/openclean/data/mapping.py:223: UserWarning: Ignoring key: BRONX (6701 matches). To include ignored keys, update the map to contain only 1 match per key
#   'update the map to contain only 1 match per key'.format(k, len(v)))
# /usr/local/lib/python3.7/dist-packages/openclean/data/mapping.py:223: UserWarning: Ignoring key: QUEENS (3532 matches). To include ignored keys, update the map to contain only 1 match per key
#   'update the map to contain only 1 match per key'.format(k, len(v)))
# /usr/local/lib/python3.7/dist-packages/openclean/data/mapping.py:223: UserWarning: Ignoring key: BROOKLYN (9734 matches). To include ignored keys, update the map to contain only 1 match per key
#   'update the map to contain only 1 match per key'.format(k, len(v)))
# /usr/local/lib/python3.7/dist-packages/openclean/data/mapping.py:223: UserWarning: Ignoring key: MANHATTAN (2922 matches). To include ignored keys, update the map to contain only 1 match per key
#   'update the map to contain only 1 match per key'.format(k, len(v)))
# /usr/local/lib/python3.7/dist-packages/openclean/data/mapping.py:223: UserWarning: Ignoring key: STATEN ISLAND (696 matches). To include ignored keys, update the map to contain only 1 match per key
#   'update the map to contain only 1 match per key'.format(k, len(v)))
# ['BRONX' 'QUEENS' 'BROOKLYN' 'MANHATTAN' 'STATEN ISLAND']

# %% [markdown]
# #### We can see that all the key codes are valid 3-digit numbers

# %%
df.filter((df.KY_CD < 100) | (df.KY_CD > 999)).count()
# Out:
# 0

# %% [markdown]
# ## Defining checks for outliers in age group

# %%
df.select('PERP_AGE_GROUP').distinct().show()
# Out:
# +--------------+
# |PERP_AGE_GROUP|
# +--------------+
# |           940|
# |           <18|
# |         25-44|
# |          null|
# |           224|
# |       UNKNOWN|
# |           65+|
# |         18-24|
# |          1020|
# |         45-64|
# +--------------+

# %% [markdown]
# #### There are no invalid age groups like negative values, unrealistically high age groups, etc.
#
# #### Lets find all the invalid age groups and replace them with `NaN`

# %%
valid_age_groups = ['<18','18-24','25-44','45-64','65+',np.NaN]
df = df.withColumn('PERP_AGE_GROUP', when(df.PERP_AGE_GROUP.isin(valid_age_groups), df.PERP_AGE_GROUP).otherwise(np.NaN))
df.show()
# Out:
# +------------+----------+----------+-------------+--------+-----------------+--------------------+-----------------------+--------------+--------+--------------+-------------+-------+--------------+--------------------+
# |INCIDENT_KEY|OCCUR_DATE|OCCUR_TIME|         BORO|PRECINCT|JURISDICTION_CODE|       LOCATION_DESC|STATISTICAL_MURDER_FLAG|PERP_AGE_GROUP|PERP_SEX|     PERP_RACE|VIC_AGE_GROUP|VIC_SEX|      VIC_RACE|             Lon_Lat|
# +------------+----------+----------+-------------+--------+-----------------+--------------------+-----------------------+--------------+--------+--------------+-------------+-------+--------------+--------------------+
# |    74925351|10/05/2010|  16:04:00|     BROOKLYN|      67|                0|     COMMERCIAL BLDG|                  false|         25-44|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.943490...|
# |   198404597|06/12/2019|  19:37:00|     BROOKLYN|      77|                0|      GROCERY/BODEGA|                   true|         25-44|       M|         BLACK|        45-64|      M|         BLACK|POINT (-73.941653...|
# |   220294221|11/09/2020|  16:48:00|       QUEENS|     101|                0|      GROCERY/BODEGA|                  false|           NaN|    null|          null|        25-44|      M|WHITE HISPANIC|POINT (-73.763268...|
# |    77758734|03/16/2011|  19:13:00|       QUEENS|     113|                0|           PVT HOUSE|                  false|         18-24|       F|         BLACK|        18-24|      M|         BLACK|POINT (-73.775909...|
# |    71608993|03/04/2010|  18:27:00|        BRONX|      50|                2|MULTI DWELL - PUB...|                   true|         18-24|       M|         BLACK|        18-24|      M|BLACK HISPANIC|POINT (-73.908011...|
# |    33008213|07/09/2007|  00:20:00|        BRONX|      47|                0|                null|                  false|         18-24|       F|WHITE HISPANIC|        18-24|      M|WHITE HISPANIC|POINT (-73.847607...|
# |    46141344|05/03/2008|  03:13:00|        BRONX|      40|                0|                null|                   true|           NaN|    null|          null|        25-44|      M|         BLACK|POINT (-73.925622...|
# |    86093515|08/04/2012|  22:29:00|        BRONX|      46|                0|                null|                   true|         18-24|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.899665...|
# |    34057961|08/29/2007|  11:02:00|STATEN ISLAND|     120|                0|   BEAUTY/NAIL SALON|                  false|         25-44|       M|         BLACK|        25-44|      M|         BLACK|POINT (-74.166234...|
# |    80149332|08/04/2011|  23:15:00|        BRONX|      42|                0|MULTI DWELL - APT...|                  false|           NaN|    null|          null|        25-44|      M|         BLACK|POINT (-73.895200...|
# |   208532947|01/26/2020|  00:27:00|        BRONX|      43|                0|      BAR/NIGHT CLUB|                  false|         25-44|       M|WHITE HISPANIC|        45-64|      M|WHITE HISPANIC|POINT (-73.864116...|
# |   144448394|07/13/2015|  01:01:00|        BRONX|      52|                0|                null|                  false|         18-24|       M|         BLACK|        18-24|      M|BLACK HISPANIC|POINT (-73.875021...|
# |   148364097|12/07/2015|  22:05:00|STATEN ISLAND|     120|                0|           PVT HOUSE|                  false|         45-64|       M|         BLACK|        25-44|      M|         BLACK|POINT (-74.081246...|
# |    80432271|08/24/2011|  04:05:00|        BRONX|      41|                0|      GROCERY/BODEGA|                  false|         25-44|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.889713...|
# |    80682814|09/11/2011|  17:11:00|       QUEENS|     105|                0|                null|                  false|           NaN|    null|          null|        18-24|      M|         BLACK|POINT (-73.753905...|
# |    51110047|09/09/2008|  14:21:00|        BRONX|      52|                0|                null|                  false|         25-44|       M|WHITE HISPANIC|        18-24|      M|BLACK HISPANIC|POINT (-73.879631...|
# |    64318199|08/02/2009|  01:44:00|    MANHATTAN|       5|                2|MULTI DWELL - PUB...|                  false|         18-24|       M|         BLACK|        25-44|      M|BLACK HISPANIC|POINT (-73.991719...|
# |   221113464|11/29/2020|  14:37:00|    MANHATTAN|      32|                0|MULTI DWELL - APT...|                  false|           NaN|    null|          null|          <18|      M|         BLACK|POINT (-73.941673...|
# |   148099938|11/26/2015|  23:36:00|     BROOKLYN|      73|                2|MULTI DWELL - PUB...|                  false|           NaN|    null|          null|        25-44|      M|         BLACK|POINT (-73.904020...|
# |    71859339|03/20/2010|  03:43:00|    MANHATTAN|      33|                0|      GROCERY/BODEGA|                  false|         25-44|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.941349...|
# +------------+----------+----------+-------------+--------+-----------------+--------------------+-----------------------+--------------+--------+--------------+-------------+-------+--------------+--------------------+
# only showing top 20 rows

# %%
df.select('PERP_AGE_GROUP').distinct().show()
# Out:
# +--------------+
# |PERP_AGE_GROUP|
# +--------------+
# |           <18|
# |         25-44|
# |           65+|
# |           NaN|
# |         18-24|
# |         45-64|
# +--------------+

# %% [markdown]
# ### Check for Race Values

# %%
df.select('PERP_RACE').distinct().show()
# Out:
# +--------------------+
# |           PERP_RACE|
# +--------------------+
# |               WHITE|
# |               BLACK|
# |AMERICAN INDIAN/A...|
# |                null|
# |      BLACK HISPANIC|
# |      WHITE HISPANIC|
# |             UNKNOWN|
# |ASIAN / PACIFIC I...|
# +--------------------+

# %% [markdown]
# #### Replace all `UNKNOWN` values with `NaN`

# %%
from pyspark.sql.functions import regexp_replace

df = df.withColumn("PERP_RACE",
  regexp_replace("PERP_RACE", "UNKNOWN", "NaN"))

# %%
df.show(100)
# Out:
# +------------+----------+----------+-------------+--------+-----------------+--------------------+-----------------------+--------------+--------+--------------+-------------+-------+--------------+--------------------+
# |INCIDENT_KEY|OCCUR_DATE|OCCUR_TIME|         BORO|PRECINCT|JURISDICTION_CODE|       LOCATION_DESC|STATISTICAL_MURDER_FLAG|PERP_AGE_GROUP|PERP_SEX|     PERP_RACE|VIC_AGE_GROUP|VIC_SEX|      VIC_RACE|             Lon_Lat|
# +------------+----------+----------+-------------+--------+-----------------+--------------------+-----------------------+--------------+--------+--------------+-------------+-------+--------------+--------------------+
# |    74925351|10/05/2010|  16:04:00|     BROOKLYN|      67|                0|     COMMERCIAL BLDG|                  false|         25-44|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.943490...|
# |   198404597|06/12/2019|  19:37:00|     BROOKLYN|      77|                0|      GROCERY/BODEGA|                   true|         25-44|       M|         BLACK|        45-64|      M|         BLACK|POINT (-73.941653...|
# |   220294221|11/09/2020|  16:48:00|       QUEENS|     101|                0|      GROCERY/BODEGA|                  false|           NaN|    null|          null|        25-44|      M|WHITE HISPANIC|POINT (-73
                0|                null|                   true|         18-24|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.922759...|
# |    67678775|11/09/2009|  18:14:00|     BROOKLYN|      73|                0|                null|                   true|         18-24|       M|         BLACK|        18-24|      M|         BLACK|POINT (-73.913554...|
# +------------+----------+----------+-------------+--------+-----------------+--------------------+-----------------------+--------------+--------+--------------+-------------+-------+--------------+--------------------+
# only showing top 100 rows

# %%
df.select('PERP_RACE').distinct().show()
# Out:
# +--------------------+
# |           PERP_RACE|
# +--------------------+
# |               WHITE|
# |               BLACK|
# |AMERICAN INDIAN/A...|
# |                null|
# |      BLACK HISPANIC|
# |      WHITE HISPANIC|
# |                 NaN|
# |ASIAN / PACIFIC I...|
# +--------------------+

# %% [markdown]
# ### Checks for Perpretrator Sex

# %%
df.select('PERP_SEX').distinct().show()
# Out:
# +--------+
# |PERP_SEX|
# +--------+
# |       F|
# |    null|
# |       M|
# |       U|
# +--------+

# %% [markdown]
# #### Checking values in suspect sex

# %%
df.groupBy('PERP_SEX').count().orderBy('count', ascending=False).show()
# Out:
# +--------+-----+
# |PERP_SEX|count|
# +--------+-----+
# |       M|13490|
# |    null| 8261|
# |       U| 1499|
# |       F|  335|
# +--------+-----+

# %% [markdown]
# #### Get unique values of offense description in sorted order

# %%
df.select('OFNS_DESC').distinct().orderBy('OFNS_DESC', ascending=True).show()
# Out:
# +--------------------+
# |           OFNS_DESC|
# +--------------------+
# |                null|
# | ADMINISTRATIVE CODE|
# |ADMINISTRATIVE CODES|
# |AGRICULTURE & MRK...|
# |ALCOHOLIC BEVERAG...|
# |ANTICIPATORY OFFE...|
# |               ARSON|
# |ASSAULT 3 & RELAT...|
# |     BURGLAR'S TOOLS|
# |            BURGLARY|
# |CHILD ABANDONMENT...|
# |CRIMINAL MISCHIEF...|
# |   CRIMINAL TRESPASS|
# |     DANGEROUS DRUGS|
# |   DANGEROUS WEAPONS|
# |  DISORDERLY CONDUCT|
# |ENDAN WELFARE INCOMP|
# |            ESCAPE 3|
# |      FELONY ASSAULT|
# |   FELONY SEX CRIMES|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# #### Getting Total Count of Offense Description

# %%
df.select('OFNS_DESC').distinct().count()
# Out:
# 64

# %%
df.groupBy('OFNS_DESC').count().show()
# Out:
# +--------------------+-----+
# |           OFNS_DESC|count|
# +--------------------+-----+
# |OTHER TRAFFIC INF...| 1209|
# |ANTICIPATORY OFFE...|   56|
# |   FELONY SEX CRIMES|    2|
# |OTHER OFFENSES RE...|  971|
# |VEHICLE AND TRAFF...| 3995|
# |KIDNAPPING & RELA...|   62|
# |HOMICIDE-NEGLIGEN...|    6|
# |OFF. AGNST PUB OR...| 2548|
# |      FELONY ASSAULT|11472|
# |ALCOHOLIC BEVERAG...|  279|
# |OFFENSES RELATED ...|    7|
# |CRIMINAL MISCHIEF...| 7007|
# |         THEFT-FRAUD|  149|
# |   THEFT OF SERVICES|  137|
# |MURDER & NON-NEGL...| 1157|
# |            JOSTLING|    4|
# |MISCELLANEOUS PEN...| 7629|
# |LOITERING/GAMBLIN...|    4|
# |               ARSON|   86|
# |OFFENSES AGAINST ...|  737|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# **Map Key Codes with Offense Description**

# %%
key_off_mapping = df.groupBy('KY_CD').agg(collect_set('OFNS_DESC').alias('OFNS_DESCS')).orderBy('KY_CD')
key_off_mapping.show()
# Out:
# +-----+--------------------+
# |KY_CD|          OFNS_DESCS|
# +-----+--------------------+
# | null|                  []|
# |  101|[MURDER & NON-NEG...|
# |  102|[HOMICIDE-NEGLIGE...|
# |  103|[HOMICIDE-NEGLIGE...|
# |  104|              [RAPE]|
# |  105|           [ROBBERY]|
# |  106|    [FELONY ASSAULT]|
# |  107|          [BURGLARY]|
# |  109|     [GRAND LARCENY]|
# |  110|[GRAND LARCENY OF...|
# |  111|[POSSESSION OF ST...|
# |  112|       [THEFT-FRAUD]|
# |  113|           [FORGERY]|
# |  114|             [ARSON]|
# |  115|[PROSTITUTION & R...|
# |  116|[SEX CRIMES, FELO...|
# |  117|   [DANGEROUS DRUGS]|
# |  118| [DANGEROUS WEAPONS]|
# |  119|[INTOXICATED/IMPA...|
# |  120|[ENDAN WELFARE IN...|
# +-----+--------------------+
# only showing top 20 rows

# %%
key_off_mapping.count()
# Out:
# 67

# %%
df.select('KY_CD').distinct().count()
# Out:
# 67

# %% [markdown]
# #### Each key code represents a particular offense description. There is a one to one mapping. So we would use key code for future analysis instead of offense description.

# %% [markdown]
# #### Calculating the null values present in the data columnwise (with respect to the features)

# %%
df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df.columns]).show()

# %%
amount_missing_df = df.select([(count(when(isnan(c) | col(c).isNull(), c))/count(lit(1))).alias(c) for c in df.columns])
amount_missing_df.show()

# %% [markdown]
# #### Thus, we can see that the percentage of null values per variable has gone considerably down after cleaning. Some variables like 'PARKS_NM', 'HADEVELOPT' and such can have null values as established above.

# %% [markdown]
# ### Number of columns in Clean Data

# %%
len(df.columns)
# Out:
# 15

# %% [markdown]
# ### Number of rows in Clean Data

# %%
df.count()
# Out:
# 23585

# %%
df.printSchema()
# Out:
# root
#  |-- INCIDENT_KEY: integer (nullable = true)
#  |-- OCCUR_DATE: string (nullable = true)
#  |-- OCCUR_TIME: string (nullable = true)
#  |-- BORO: string (nullable = true)
#  |-- PRECINCT: integer (nullable = true)
#  |-- JURISDICTION_CODE: integer (nullable = true)
#  |-- LOCATION_DESC: string (nullable = true)
#  |-- STATISTICAL_MURDER_FLAG: boolean (nullable = true)
#  |-- PERP_AGE_GROUP: string (nullable = true)
#  |-- PERP_SEX: string (nullable = true)
#  |-- PERP_RACE: string (nullable = true)
#  |-- VIC_AGE_GROUP: string (nullable = true)
#  |-- VIC_SEX: string (nullable = true)
#  |-- VIC_RACE: string (nullable = true)
#  |-- Lon_Lat: string (nullable = true)

# %% [markdown]
# ### **Exporting Clean Data in CSV**
#
# The Cleaned Data Set will be saved as `NYPD_Complaint_Data_Historic_Cleaned.csv`

# %%
pd_df = df.toPandas()
pd_df.to_csv("NYPD_Arrest_Data_Year_to_Date_Cleaned_Spark.csv")
